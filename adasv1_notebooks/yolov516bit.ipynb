# %%
# Define paths to the train, val, and test directories
train_images_dir = '/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/train/thermal16bitwithlabels/images'
val_images_dir = '/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/val/thermal16bitwithlabels/images'
test_images_dir = '/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal16bitwithlabels/images'  # Optional

# Path where you want to save your dataset.yaml file
yaml_file_path = '/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal16bit.yaml'

# Number of classes and their names
num_classes = 4
class_names = ['person', 'bicycle', 'car', 'dog']

# Create the YAML file content
yaml_content = f"""
# Paths to the training and validation datasets
train: {train_images_dir}
val: {val_images_dir}

# Optional: Path to the test dataset (if you have one)
test: {test_images_dir}

# Number of classes
nc: {num_classes}

# Class names
names: {class_names}
"""

# Write the content to the dataset.yaml file
with open(yaml_file_path, 'w') as yaml_file:
    yaml_file.write(yaml_content)

print(f'dataset.yaml created at: {yaml_file_path}')
# Out:
# dataset.yaml created at: /home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal16bit.yaml

# %%
# Path to your YAML file
yaml_file_path = '/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal16bit.yaml'  # Adjust this if needed

# Read and print the contents of the YAML file
with open(yaml_file_path, 'r') as yaml_file:
    yaml_contents = yaml_file.read()

print("Contents of the YAML file:")
print(yaml_contents)
# Out:
# Contents of the YAML file:
#
# # Paths to the training and validation datasets
# train: /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/train/thermal16bitwithlabels/images
# val: /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/val/thermal16bitwithlabels/images
#
# # Optional: Path to the test dataset (if you have one)
# test: /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal16bitwithlabels/images
#
# # Number of classes
# nc: 4
#
# # Class names
# names: ['person', 'bicycle', 'car', 'dog']

# %%
# Install necessary packages
# %pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd /home/deepaksr/project/project_assignment2/adas_v1/yolov5
# Out:
# /home/deepaksr/project/project_assignment2/adas_v1/yolov5

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /home/deepaksr/project/project_assignment2/adas_v1/yolov5

# %%
img_size = 640  # Image size
batch_size = 32  # Batch size
epochs = 21  # Number of epochs
data_yaml_path = '/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal16bit.yaml'  # Path to your dataset YAML file
weights = 'yolov5s.pt'  # Pre-trained weights
device = '0,1,2,3'  # Use '0' for first GPU

# !python train.py --img {img_size} --batch {batch_size} --epochs {epochs} --data {data_yaml_path} --weights {weights} --device {device}
# Out:
# train: weights=yolov5s.pt, cfg=, data=/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal16bit.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=21, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 17 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-371-g6629839d Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
# ...

# %%
# !python val.py --weights /home/deepaksr/project/project_assignment2/adas_v1/yolov5/runs/train/exp22/weights/best.pt --data /home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal16bit.yaml --img 640 --task test --device 1
# Out:
# val: data=/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal16bit.yaml, weights=['/home/deepaksr/project/project_assignment2/adas_v1/yolov5/runs/train/exp22/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=1, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-371-g6629839d Python-3.8.20 torch-2.4.1+cu121 CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/
# test: WARNING ⚠️ /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal16bitwithlabels/images/FLIR_video_02466.tiff: 1 duplicate labels removed
# ...
