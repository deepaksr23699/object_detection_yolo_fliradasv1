# %%
import zipfile

# Specify the path to your zip file and the extraction directory
zip_file_path = '/home/deepaksr/project/project_assignment2/adas_v1/archive (6).zip'
extraction_path = '/home/deepaksr/project/project_assignment2/adas_v1'

# Open the zip file and extract its contents
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

# %%
# %pip install globox
# Out:
# ...
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 72.8 MB/s eta 0:00:00:00:01
# ...
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from globox import AnnotationSet # type: ignore
coco_annotations_train = AnnotationSet.from_coco(file_path="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/train/thermal_annotations.json")
coco_annotations_train.show_stats()
coco_annotations_val = AnnotationSet.from_coco(file_path="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/val/thermal_annotations.json")
coco_annotations_val.show_stats()
# Out:
#           Database Stats
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ Label         ┃ Images ┃ Boxes ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ <empty_image> │   1002 │     0 │
# │ bicycle       │   1762 │  3986 │
# │ car           │   7379 │ 41260 │
# │ dog           │    202 │   226 │
# │ person        │   5838 │ 22372 │
# ├───────────────┼────────┼───────┤
# │ Total         │   8862 │ 67844 │
# └───────────────┴────────┴───────┘
#           Database Stats
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃ Label         ┃ Images ┃ Boxes ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ <empty_image> │      6 │     0 │
# │ bicycle       │    338 │   471 │
# │ car           │   1292 │  5432 │
# │ dog           │     14 │    14 │
# │ person        │   1206 │  5779 │
# ├───────────────┼────────┼───────┤
# │ Total         │   1366 │ 11696 │
# └───────────────┴────────┴───────┘

# %%
from globox import AnnotationSet # type: ignore

# Load train COCO annotations
coco_annotations_train = AnnotationSet.from_coco(file_path="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/train/thermal_annotations.json")

# Define the label to id mapping
label_to_id = {
    "person": 0, "bicycle": 1, "car": 2, "dog": 3
}

# Convert and save in YOLOv5 format
coco_annotations_train.save_yolo_v5(
    save_dir="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/train/labels",
    label_to_id=label_to_id
)

# %%
# Load val COCO annotations
coco_annotations_val = AnnotationSet.from_coco(file_path="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/val/thermal_annotations.json")

# Define the label to id mapping
label_to_id = {
    "person": 0, "bicycle": 1, "car": 2, "dog": 3
}

# Convert and save in YOLOv5 format
coco_annotations_val.save_yolo_v5(
    save_dir="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/val/labels",
    label_to_id=label_to_id
)

# %%
# Load test COCO annotations
coco_annotations_val = AnnotationSet.from_coco(file_path="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal_annotations.json")

# Define the label to id mapping
label_to_id = {
    "person": 0, "bicycle": 1, "car": 2, "dog": 3
}

# Convert and save in YOLOv5 format
coco_annotations_val.save_yolo_v5(
    save_dir="/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/tbd",
    label_to_id=label_to_id
)

# %%
# Define paths to the train, val, and test directories
train_images_dir = '/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/train/thermal8bitwithlabels/images'
val_images_dir = '/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/val/thermal8bitwithlabels/images'
test_images_dir = '/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal8bitwithlabels/images'  # Optional

# Path where you want to save your dataset.yaml file
yaml_file_path = '/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal8bit.yaml'

# Number of classes and their names
num_classes = 4
class_names = ['person', 'bicycle', 'car', 'dog']

# Create the YAML file content
yaml_content = f"""
# Paths to the training and validation datasets
train: {train_images_dir}
val: {val_images_dir}

# Optional: Path to the test dataset (if you have one)
test: {test_images_dir}

# Number of classes
nc: {num_classes}

# Class names
names: {class_names}
"""

# Write the content to the dataset.yaml file
with open(yaml_file_path, 'w') as yaml_file:
    yaml_file.write(yaml_content)

print(f'dataset.yaml created at: {yaml_file_path}')
# Out:
# dataset.yaml created at: /home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal8bit.yaml

# %%
# Path to your YAML file
yaml_file_path = '/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal8bit.yaml'  # Adjust this if needed

# Read and print the contents of the YAML file
with open(yaml_file_path, 'r') as yaml_file:
    yaml_contents = yaml_file.read()

print("Contents of the YAML file:")
print(yaml_contents)
# Out:
# Contents of the YAML file:
#
# # Paths to the training and validation datasets
# train: /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/train/thermal8bitwithlabels/images
# val: /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/val/thermal8bitwithlabels/images
#
# # Optional: Path to the test dataset (if you have one)
# test: /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal8bitwithlabels/images
#
# # Number of classes
# nc: 4
#
# # Class names
# names: ['person', 'bicycle', 'car', 'dog']

# %%
# Install necessary packages
# %pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt
# Out:
# ...
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# ...
#   Using cached PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (26 kB)
# ...
#   Using cached torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.0 kB)
# ...
#   Using cached ultralytics-8.3.9-py3-none-any.whl.metadata (34 kB)
# ...

# %%
# %cd /home/deepaksr/project/project_assignment2/adas_v1/yolov5
# Out:
# /home/deepaksr/project/project_assignment2/adas_v1/yolov5

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /home/deepaksr/project/project_assignment2/adasv1_notebooks/yolov5

# %%
img_size = 640  # Image size
batch_size = 48  # Batch size
epochs = 21  # Number of epochs
data_yaml_path = '/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal8bit.yaml'  # Path to your dataset YAML file
weights = 'yolov5s.pt'  # Pre-trained weights
device = '0,1,2,3'  # Use '0' for first GPU

# !python train.py --img {img_size} --batch {batch_size} --epochs {epochs} --data {data_yaml_path} --weights {weights} --device {device}
# Out:
# train: weights=yolov5s.pt, cfg=, data=/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal8bit.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=21, batch_size=48, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# ...

# %%
# !python detect.py --weights /home/deepaksr/project/project_assignment2/adas_v1/yolov5/runs/train/exp21/weights/best.pt --img 640 --conf 0.25 --source /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal8bitwithlabels/images --device 1 --save-txt --save-conf
# Out:
# detect: weights=['/home/deepaksr/project/project_assignment2/adas_v1/yolov5/runs/train/exp21/weights/best.pt'], source=/home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal8bitwithlabels/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=1, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-371-g6629839d Python-3.8.20 torch-2.4.1+cu121 CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %%
# !python val.py --weights /home/deepaksr/project/project_assignment2/adas_v1/yolov5/runs/train/exp21/weights/best.pt --data /home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal8bit.yaml --img 640 --task test --device 1
# Out:
# val: data=/home/deepaksr/project/project_assignment2/adasv1_notebooks/thermal8bit.yaml, weights=['/home/deepaksr/project/project_assignment2/adas_v1/yolov5/runs/train/exp21/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=1, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-371-g6629839d Python-3.8.20 torch-2.4.1+cu121 CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/
# test: WARNING ⚠️ /home/deepaksr/project/project_assignment2/adas_v1/FLIR_ADAS_1_3/video/thermal8bitwithlabels/images/FLIR_video_02466.jpeg: 1 duplicate labels removed
# ...
